# %%
# !pip install sayswho

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ----- ---------------------------------- 1.8/12.8 MB 10.0 MB/s eta 0:00:02
#      ------------ --------------------------- 3.9/12.8 MB 11.2 MB/s eta 0:00:01
#      -------------------- ------------------- 6.6/12.8 MB 10.6 MB/s eta 0:00:01
#      --------------------------- ------------ 8.9/12.8 MB 10.6 MB/s eta 0:00:01
#      ------------------------------------ -- 12.1/12.8 MB 11.4 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 11.2 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# !pip install https://github.com/explosion/spacy-experimental/releases/download/v0.6.1/en_coreference_web_trf-3.4.0a2-py3-none-any.whl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/490.3 MB ? eta -:--:--
#      ---------------------------------------- 1.8/490.3 MB 9.2 MB/s eta 0:00:54
#      ---------------------------------------- 3.4/490.3 MB 8.1 MB/s eta 0:01:01
#      ---------------------------------------- 5.5/490.3 MB 8.6 MB/s eta 0:00:57
#       --------------------------------------- 7.6/490.3 MB 9.0 MB/s eta 0:00:54
#       --------------------------------------- 9.7/490.3 MB 9.2 MB/s eta 0:00:53
#       -------------------------------------- 11.3/490.3 MB 8.7 MB/s eta 0:00:56
#      - ------------------------------------- 12.8/490.3 MB 8.6 MB/s eta 0:00:56
#      - ------------------------------------- 15.2/490.3 MB 8.8 MB/s eta 0:00:55
#      - ------------------------------------- 17.6/490.3 MB 9.1 MB/s eta 0:00:53
#      - ------------------------------------- 19.7/490.3 MB 9.2 MB/s eta 0:00:52
# ...

# %%
# !pip install spacy -U

# %%
# !python -m spacy download en_core_web_lg

# %%
# !python -m spacy download en_coreference_web_trf
# Out:
# ✘ No compatible package found for 'en_coreference_web_trf' (spaCy
# v3.8.2)

# %%
from sayswho import SaysWho

text = """Nets Coach Jacque Vaughn was optimistic when discussing Ben Simmons's prospects on NBA TV.

“It’s been great, being able to check in with Ben," Vaughn said, via Nets Daily. “I look forward to coaching a healthy Ben Simmons. The team is excited to have him healthy, being part of our program and moving forward.

"He has an innate ability to impact the basketball game on both ends of the floor. So, we missed that in the Philly series and looking forward to it.”

Simmons arrived in Brooklyn during the 2021-22 season, but did not play that year after a back injury. The 26-year-old would make 42 appearances (33 starts) during a tumult-filled season for Brooklyn.

“He is on the court. No setbacks," Vaughn later told reporters about Simmons' workouts. “We’ll continue to see him improve through the offseason.”"""

sw = SaysWho(text, coref_nlp="en_coreference_web_trf", base_nlp="en_core_web_trf")

print(sw.quotes)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 13
#       1 from sayswho import SaysWho
#       3 text = """Nets Coach Jacque Vaughn was optimistic when discussing Ben Simmons's prospects on NBA TV.
#       4
#       5 “It’s been great, being able to check in with Ben," Vaughn said, via Nets Daily. “I look forward to coaching a healthy Ben Simmons. The team is excited to have him healthy, being part of our program and moving forward.
#    (...)
#      10
#      11 “He is on the court. No setbacks," Vaughn later told reporters about Simmons' workouts. “We’ll continue to see him improve through the offseason.”"""
# ---> 13 sw = SaysWho(text)
#      15 print(sw.quotes)
#
# File d:\envs\annotate\lib\site-packages\sayswho\__init__.py:32, in SaysWho.__init__(self, text, coref_nlp, base_nlp, prune, prep_text)
#      30 for v in ["coref_nlp", "base_nlp"]:
# ...

# %%
import spacy
import sayswho
import os
from pathlib import Path

# %%
import spacy
from sayswho import stance

# Load the spaCy model
nlp = spacy.load("en_core_web_sm")

# Example text
text = "I strongly disagree with the statement that climate change is a hoax."

# Use the sayswho stance detection method directly
stance_prediction = stance(text)

print(f'Stance prediction: {stance_prediction}')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 2
#       1 import spacy
# ----> 2 from sayswho import stance
#       4 # Load the spaCy model
#       5 nlp = spacy.load("en_core_web_sm")
#
# ImportError: cannot import name 'stance' from 'sayswho' (d:\envs\annotate\lib\site-packages\sayswho\__init__.py)
