# %%
# Using spacy.load().
import spacy
nlp = spacy.load("en_docusco_spacy")

# Importing as module.
import en_docusco_spacy
nlp = en_docusco_spacy.load()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import spacy
from tmtoolkit.corpus import Corpus, vocabulary_size, corpus_num_tokens
import re

def pre_process(txt):
    txt = re.sub(r'\bits\b', 'it s', txt)
    txt = re.sub(r'\bIts\b', 'It s', txt)
    txt = " ".join(txt.split())
    return(txt)

# %% [markdown]
# # Convert Corpus
# ## Basic information about the twitter_sentiment_data.csv

# %%
import pandas as pd

# Load only the first 1000 rows from the CSV file
df = pd.read_csv('twitter_sentiment_data.csv').head(100)

# Save the subset to a temporary CSV file
df.to_csv('twitter_sentiment_data_1000sample.csv', index=False)

# %%
corp = Corpus.from_tabular(
    'twitter_sentiment_data_1000sample.csv',
    id_column = "tweetid",
    text_column="message",  # Specify the column containing the preprocessed text
    spacy_instance=nlp,  # Use the spaCy instance for processing
    spacy_token_attrs=["tag", "ent_iob", "ent_type", "is_punct"]  # Token attributes to include
)

corpus_total = corpus_num_tokens(corp)
corpus_types = vocabulary_size(corp)
total_punct = []
for i in range(0,len(corp)):
    total_punct.append(sum(corp[i]['is_punct']))
total_punct = sum(total_punct)
non_punct = corpus_total - total_punct

# %%
print('Aphanumeric tokens:', non_punct, '\nPunctuation tokens:', total_punct, '\nTotal tokens:', corpus_total, '\nToken types:', corpus_types)
# Out:
# Aphanumeric tokens: 1855
# Punctuation tokens: 320
# Total tokens: 2175
# Token types: 681

# %% [markdown]
# ## Trial 1.1 Frequency Table (with stopwords)

# %%
from docuscospacy import convert_corpus, frequency_table, tags_table, ngrams_by_token, ngrams_by_tag, coll_table, tags_dtm, normalize_dtm, dtm_to_coo, kwic_center_node, keyness_table, tag_ruler

# %%
tp = convert_corpus(corp)

wc = frequency_table(tp, non_punct)

# %% [markdown]
# * AF (Absolute Frequency): The total number of times the token appears in the corpus.
# * RF (Relative Frequency): The frequency of the token adjusted for corpus size, typically expressed as occurrences per million words (or similar)。
# * Range: The percentage of documents in the corpus where the token appears. For example, if the range is 77.05, the token climate appears in 77.05% of the documents.

# %%
wc.head(20).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_19dae">
#   <thead>
#     <tr>
#       <th id="T_19dae_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_19dae_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_19dae_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_19dae_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_19dae_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_19dae_row0_col0" class="data row0 col0" >climate</td>
#       <td id="T_19dae_row0_col1" class="data row0 col1" >NN1</td>
#       <td id="T_19dae_row0_col2" class="data row0 col2" >79</td>
#       <td id="T_19dae_row0_col3" class="data row0 col3" >42587.60</td>
#       <td id="T_19dae_row0_col4" class="data row0 col4" >79.00</td>
#     </tr>
#     <tr>
#       <td id="T_19dae_row1_col0" class="data row1 col0" >change</td>
#       <td id="T_19dae_row1_col1" class="data row1 col1" >NN1</td>
#       <td id="T_19dae_row1_col2" class="data row1 col2" >74</td>
#       <td id="T_19dae_row1_col3" class="data row1 col3" >39892.18</td>
#       <td id="T_19dae_row1_col4" class="data row1 col4" >74.00</td>
#     </tr>
#     <tr>
#       <td id="T_19dae_row2_col0" class="data row2 col0" >rt</td>
#       <td id="T_19dae_row2_col1" class="data row2 col1" >NP1</td>
#       <td id="T_19dae_row2_col2" class="data row2 col2" >53</td>
#       <td id="T_19dae_row2_col3" class="data row2 col3" >28571.43</td>
#       <td id="T_19dae_row2_col4" class="data row2 col4" >53.00</td>
#     </tr>
#     <tr>
#       <td id="T_19dae_row3_col0" class="data row3 col0" >the</td>
#       <td id="T_19dae_row3_col1" class="data row3 col1" >AT</td>
#       <td id="T_19dae_row3_col2" class="data row3 col2" >46</td>
#       <td id="T_19dae_row3_col3" class="data row3 col3" >24797.84</td>
#       <td id="T_19dae_row3_col4" class="data row3 col4" >43.00</td>
#     </tr>
#     <tr>
#       <td id="T_19dae_row4_col0" class="data row4 col0" >to</td>
#       <td id="T_19dae_row4_col1" class="data row4 col1" >TO</td>
#       <td id="T_19dae_row4_col2" class="data row4 col2" >33</td>
#       <td id="T_19dae_row4_col3" class="data row4 col3" >17789.76</td>
#       <td id="T_19dae_row4_col4" class="data row4 col4" >31.00</td>
#     </tr>
#     <tr>
#       <td id="T_19dae_row5_col0" class="data row5 col0" >global</td>
#       <td id="T_19dae_row5_col1" class="data row5 col1" >JJ</td>
#       <td id="T_19dae_row5_col2" class="data row5 col2" >25</td>
#       <td id="T_19dae_row5_col3" class="data row5 col3" >13477.09</td>
#       <td id="T_19dae_row5_col4" class="data row5 col4" >25.00</td>
#     </tr>
#     <tr>
#       <td id="T_19dae_row6_col0" class="data row6 col0" >as</td>
#       <td id="T_19dae_row6_col1" class="data row6 col1" >CSA</td>
#       <td id="T_19dae_row6_col2" class="data row6 col2" >23</td>
#       <td id="T_19dae_row6_col3" class="data row6 col3" >12398.92</td>
#       <td id="T_19dae_row6_col4" class="data row6 col4" >23.00</td>
#     </tr>
#     <tr>
#       <td id="T_19dae_row7_col0" class="data row7 col0" >beforetheflood</td>
#       <td id="T_19dae_row7_col1" class="data row7 col1" >NP1</td>
#       <td id="T_19dae_row7_col2" class="data row7 col2" >23</td>
#       <td id="T_19dae_row7_col3" class="data row7 col3" >12398.92</td>
#       <td id="T_19dae_row7_col4" class="data row7 col4" >22.00</td>
#     </tr>
#     <tr>
#       <td id="T_19dae_row8_col0" class="data row8 col0" >here</td>
#       <td id="T_19dae_row8_col1" class="data row8 col1" >RL</td>
#       <td id="T_19dae_row8_col2" class="data row8 col2" >22</td>
#       <td id="T_19dae_row8_col3" class="data row8 col3" >11859.84</td>
#       <td id="T_19dae_row8_col4" class="data row8 col4" >22.00</td>
#     </tr>
#     <tr>
#       <td id="T_19dae_row9_col0" class="data row9 col0" >is</td>
#       <td id="T_19dae_row9_col1" class="data row9 col1" >VBZ</td>
#       <td id="T_19dae_row9_col2" class="data row9 col2" >22</td>
#       <td id="T_19dae_row9_col3" class="data row9 col3" >11859.84</td>
#       <td id="T_19dae_row9_col4" class="data row9 col4" >20.00</td>
#     </tr>
#     <tr>
#       <td id="T_19dae_row10_col0" class="data row10 col0" >warming</td>
#       <td id="T_19dae_row10_col1" class="data row10 col1" >NN1</td>
#       <td id="T_19dae_row10_col2" class="data row10 col2" >22</td>
#       <td id="T_19dae_row10_col3" class="data row10 col3" >11859.84</td>
#       <td id="T_19dae_row10_col4" class="data row10 col4" >22.00</td>
#     </tr>
#     <tr>
#       <td id="T_19dae_row11_col0" class="data row11 col0" >watch</td>
#       <td id="T_19dae_row11_col1" class="data row11 col1" >VV0</td>
#       <td id="T_19dae_row11_col2" class="data row11 col2" >22</td>
#       <td id="T_19dae_row11_col3" class="data row11 col3" >11859.84</td>
#       <td id="T_19dae_row11_col4" class="data row11 col4" >22.00</td>
#     </tr>
#     <tr>
#       <td id="T_19dae_row12_col0" class="data row12 col0" >world</td>
#       <td id="T_19dae_row12_col1" class="data row12 col1" >NN1</td>
#       <td id="T_19dae_row12_col2" class="data row12 col2" >21</td>
#       <td id="T_19dae_row12_col3" class="data row12 col3" >11320.75</td>
#       <td id="T_19dae_row12_col4" class="data row12 col4" >21.00</td>
#     </tr>
#     <tr>
#       <td id="T_19dae_row13_col0" class="data row13 col0" >and</td>
#       <td id="T_19dae_row13_col1" class="data row13 col1" >CC</td>
#       <td id="T_19dae_row13_col2" class="data row13 col2" >20</td>
#       <td id="T_19dae_row13_col3" class="data row13 col3" >10781.67</td>
#       <td id="T_19dae_row13_col4" class="data row13 col4" >20.00</td>
#     </tr>
#     <tr>
#       <td id="T_19dae_row14_col0" class="data row14 col0" >@leodicaprio</td>
#       <td id="T_19dae_row14_col1" class="data row14 col1" >NN1</td>
#       <td id="T_19dae_row14_col2" class="data row14 col2" >19</td>
#       <td id="T_19dae_row14_col3" class="data row14 col3" >10242.59</td>
#       <td id="T_19dae_row14_col4" class="data row14 col4" >19.00</td>
#     </tr>
#     <tr>
#       <td id="T_19dae_row15_col0" class="data row15 col0" >a</td>
#       <td id="T_19dae_row15_col1" class="data row15 col1" >AT1</td>
#       <td id="T_19dae_row15_col2" class="data row15 col2" >19</td>
#       <td id="T_19dae_row15_col3" class="data row15 col3" >10242.59</td>
#       <td id="T_19dae_row15_col4" class="data row15 col4" >18.00</td>
#     </tr>
#     <tr>
#       <td id="T_19dae_row16_col0" class="data row16 col0" >@natgeochannel</td>
#       <td id="T_19dae_row16_col1" class="data row16 col1" >FO</td>
#       <td id="T_19dae_row16_col2" class="data row16 col2" >18</td>
#       <td id="T_19dae_row16_col3" class="data row16 col3" >9703.50</td>
#       <td id="T_19dae_row16_col4" class="data row16 col4" >18.00</td>
#     </tr>
#     <tr>
#       <td id="T_19dae_row17_col0" class="data row17 col0" >in</td>
#       <td id="T_19dae_row17_col1" class="data row17 col1" >II</td>
#       <td id="T_19dae_row17_col2" class="data row17 col2" >17</td>
#       <td id="T_19dae_row17_col3" class="data row17 col3" >9164.42</td>
#       <td id="T_19dae_row17_col4" class="data row17 col4" >16.00</td>
#     </tr>
#     <tr>
#       <td id="T_19dae_row18_col0" class="data row18 col0" >it</td>
#       <td id="T_19dae_row18_col1" class="data row18 col1" >PPH1</td>
#       <td id="T_19dae_row18_col2" class="data row18 col2" >17</td>
#       <td id="T_19dae_row18_col3" class="data row18 col3" >9164.42</td>
#       <td id="T_19dae_row18_col4" class="data row18 col4" >16.00</td>
#     </tr>
#     <tr>
#       <td id="T_19dae_row19_col0" class="data row19 col0" >right</td>
#       <td id="T_19dae_row19_col1" class="data row19 col1" >RR</td>
#       <td id="T_19dae_row19_col2" class="data row19 col2" >17</td>
#       <td id="T_19dae_row19_col3" class="data row19 col3" >9164.42</td>
#       <td id="T_19dae_row19_col4" class="data row19 col4" >17.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Trial 1.2 Frequency Table (without stopwords)

# %%
import pandas as pd
import spacy
from tmtoolkit.corpus import Corpus, vocabulary_size, corpus_num_tokens

# Load SpaCy model
nlp = spacy.load("en_core_web_sm")
nlp.Defaults.stop_words.add("rt")  # Add "rt" to stopwords

# Load the CSV
csv_path = "twitter_sentiment_data.csv"
df = pd.read_csv(csv_path).head(1000)

# Preprocess the text
def pre_process(txt):
    doc = nlp(txt)
    # Filter out stopwords and punctuation
    filtered_tokens = [token.text for token in doc if not token.is_stop and not token.is_punct]
    return " ".join(filtered_tokens)

# Apply the preprocessing to the text column
df['message'] = df['message'].apply(pre_process)

output_path = "twitter_sentiment_data_preprocessed_1000.csv"
df.to_csv(output_path, index=False)

# %%
corp = Corpus.from_tabular(
    "twitter_sentiment_data_preprocessed_1000.csv",  # Path to the preprocessed CSV
    id_column="tweetid",  # If you have an ID column
    text_column="message",  # Specify the preprocessed text column
    spacy_instance=nlp,  # Use your SpaCy instance
    spacy_token_attrs=["tag", "ent_iob", "ent_type", "is_punct"]  # Token attributes to include
)

corpus_total = corpus_num_tokens(corp)
corpus_types = vocabulary_size(corp)
total_punct = []
for i in range(0,len(corp)):
    total_punct.append(sum(corp[i]['is_punct']))
total_punct = sum(total_punct)
non_punct = corpus_total - total_punct

# %%
tp = convert_corpus(corp)

wc = frequency_table(tp, non_punct)

# %%
wc.head(30).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e697b">
#   <thead>
#     <tr>
#       <th id="T_e697b_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_e697b_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_e697b_level0_col2" class="col_heading level0 col2" >AF</th>
#       <th id="T_e697b_level0_col3" class="col_heading level0 col3" >RF</th>
#       <th id="T_e697b_level0_col4" class="col_heading level0 col4" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e697b_row0_col0" class="data row0 col0" >climate</td>
#       <td id="T_e697b_row0_col1" class="data row0 col1" >NN</td>
#       <td id="T_e697b_row0_col2" class="data row0 col2" >806</td>
#       <td id="T_e697b_row0_col3" class="data row0 col3" >68143.39</td>
#       <td id="T_e697b_row0_col4" class="data row0 col4" >79.10</td>
#     </tr>
#     <tr>
#       <td id="T_e697b_row1_col0" class="data row1 col0" >change</td>
#       <td id="T_e697b_row1_col1" class="data row1 col1" >NN</td>
#       <td id="T_e697b_row1_col2" class="data row1 col2" >751</td>
#       <td id="T_e697b_row1_col3" class="data row1 col3" >63493.41</td>
#       <td id="T_e697b_row1_col4" class="data row1 col4" >74.80</td>
#     </tr>
#     <tr>
#       <td id="T_e697b_row2_col0" class="data row2 col0" >global</td>
#       <td id="T_e697b_row2_col1" class="data row2 col1" >JJ</td>
#       <td id="T_e697b_row2_col2" class="data row2 col2" >222</td>
#       <td id="T_e697b_row2_col3" class="data row2 col3" >18769.02</td>
#       <td id="T_e697b_row2_col4" class="data row2 col4" >21.90</td>
#     </tr>
#     <tr>
#       <td id="T_e697b_row3_col0" class="data row3 col0" >warming</td>
#       <td id="T_e697b_row3_col1" class="data row3 col1" >NN</td>
#       <td id="T_e697b_row3_col2" class="data row3 col2" >200</td>
#       <td id="T_e697b_row3_col3" class="data row3 col3" >16909.03</td>
#       <td id="T_e697b_row3_col4" class="data row3 col4" >19.90</td>
#     </tr>
#     <tr>
#       <td id="T_e697b_row4_col0" class="data row4 col0" >@leodicaprio</td>
#       <td id="T_e697b_row4_col1" class="data row4 col1" >NNP</td>
#       <td id="T_e697b_row4_col2" class="data row4 col2" >139</td>
#       <td id="T_e697b_row4_col3" class="data row4 col3" >11751.78</td>
#       <td id="T_e697b_row4_col4" class="data row4 col4" >13.90</td>
#     </tr>
#     <tr>
#       <td id="T_e697b_row5_col0" class="data row5 col0" >world</td>
#       <td id="T_e697b_row5_col1" class="data row5 col1" >NN</td>
#       <td id="T_e697b_row5_col2" class="data row5 col2" >128</td>
#       <td id="T_e697b_row5_col3" class="data row5 col3" >10821.78</td>
#       <td id="T_e697b_row5_col4" class="data row5 col4" >12.80</td>
#     </tr>
#     <tr>
#       <td id="T_e697b_row6_col0" class="data row6 col0" >beforetheflood</td>
#       <td id="T_e697b_row6_col1" class="data row6 col1" >NN</td>
#       <td id="T_e697b_row6_col2" class="data row6 col2" >124</td>
#       <td id="T_e697b_row6_col3" class="data row6 col3" >10483.60</td>
#       <td id="T_e697b_row6_col4" class="data row6 col4" >12.40</td>
#     </tr>
#     <tr>
#       <td id="T_e697b_row7_col0" class="data row7 col0" >watch</td>
#       <td id="T_e697b_row7_col1" class="data row7 col1" >VB</td>
#       <td id="T_e697b_row7_col2" class="data row7 col2" >121</td>
#       <td id="T_e697b_row7_col3" class="data row7 col3" >10229.96</td>
#       <td id="T_e697b_row7_col4" class="data row7 col4" >12.10</td>
#     </tr>
#     <tr>
#       <td id="T_e697b_row8_col0" class="data row8 col0" >httã¢â‚¬â</td>
#       <td id="T_e697b_row8_col1" class="data row8 col1" >NNP</td>
#       <td id="T_e697b_row8_col2" class="data row8 col2" >115</td>
#       <td id="T_e697b_row8_col3" class="data row8 col3" >9722.69</td>
#       <td id="T_e697b_row8_col4" class="data row8 col4" >11.50</td>
#     </tr>
#     <tr>
#       <td id="T_e697b_row9_col0" class="data row9 col0" >right</td>
#       <td id="T_e697b_row9_col1" class="data row9 col1" >UH</td>
#       <td id="T_e697b_row9_col2" class="data row9 col2" >105</td>
#       <td id="T_e697b_row9_col3" class="data row9 col3" >8877.24</td>
#       <td id="T_e697b_row9_col4" class="data row9 col4" >10.50</td>
#     </tr>
#     <tr>
#       <td id="T_e697b_row10_col0" class="data row10 col0" >tackle</td>
#       <td id="T_e697b_row10_col1" class="data row10 col1" >NN</td>
#       <td id="T_e697b_row10_col2" class="data row10 col2" >104</td>
#       <td id="T_e697b_row10_col3" class="data row10 col3" >8792.70</td>
#       <td id="T_e697b_row10_col4" class="data row10 col4" >10.40</td>
#     </tr>
#     <tr>
#       <td id="T_e697b_row11_col0" class="data row11 col0" >travels</td>
#       <td id="T_e697b_row11_col1" class="data row11 col1" >VBZ</td>
#       <td id="T_e697b_row11_col2" class="data row11 col2" >104</td>
#       <td id="T_e697b_row11_col3" class="data row11 col3" >8792.70</td>
#       <td id="T_e697b_row11_col4" class="data row11 col4" >10.40</td>
#     </tr>
#     <tr>
#       <td id="T_e697b_row12_col0" class="data row12 col0" >@natgeochannel</td>
#       <td id="T_e697b_row12_col1" class="data row12 col1" >UH</td>
#       <td id="T_e697b_row12_col2" class="data row12 col2" >102</td>
#       <td id="T_e697b_row12_col3" class="data row12 col3" >8623.61</td>
#       <td id="T_e697b_row12_col4" class="data row12 col4" >10.20</td>
#     </tr>
#     <tr>
#       <td id="T_e697b_row13_col0" class="data row13 col0" >https://t.co/lkdehj3tnn</td>
#       <td id="T_e697b_row13_col1" class="data row13 col1" >PRP</td>
#       <td id="T_e697b_row13_col2" class="data row13 col2" >102</td>
#       <td id="T_e697b_row13_col3" class="data row13 col3" >8623.61</td>
#       <td id="T_e697b_row13_col4" class="data row13 col4" >10.20</td>
#     </tr>
#     <tr>
#       <td id="T_e697b_row14_col0" class="data row14 col0" >trump</td>
#       <td id="T_e697b_row14_col1" class="data row14 col1" >NNP</td>
#       <td id="T_e697b_row14_col2" class="data row14 col2" >99</td>
#       <td id="T_e697b_row14_col3" class="data row14 col3" >8369.97</td>
#       <td id="T_e697b_row14_col4" class="data row14 col4" >9.60</td>
#     </tr>
#     <tr>
#       <td id="T_e697b_row15_col0" class="data row15 col0" >china</td>
#       <td id="T_e697b_row15_col1" class="data row15 col1" >NNP</td>
#       <td id="T_e697b_row15_col2" class="data row15 col2" >70</td>
#       <td id="T_e697b_row15_col3" class="data row15 col3" >5918.16</td>
#       <td id="T_e697b_row15_col4" class="data row15 col4" >6.60</td>
#     </tr>
#     <tr>
#       <td id="T_e697b_row16_col0" class="data row16 col0" >plan</td>
#       <td id="T_e697b_row16_col1" class="data row16 col1" >NN</td>
#       <td id="T_e697b_row16_col2" class="data row16 col2" >58</td>
#       <td id="T_e697b_row16_col3" class="data row16 col3" >4903.62</td>
#       <td id="T_e697b_row16_col4" class="data row16 col4" >5.70</td>
#     </tr>
#     <tr>
#       <td id="T_e697b_row17_col0" class="data row17 col0" >documentary</td>
#       <td id="T_e697b_row17_col1" class="data row17 col1" >NN</td>
#       <td id="T_e697b_row17_col2" class="data row17 col2" >53</td>
#       <td id="T_e697b_row17_col3" class="data row17 col3" >4480.89</td>
#       <td id="T_e697b_row17_col4" class="data row17 col4" >5.30</td>
#     </tr>
#     <tr>
#       <td id="T_e697b_row18_col0" class="data row18 col0" >exit</td>
#       <td id="T_e697b_row18_col1" class="data row18 col1" >NN</td>
#       <td id="T_e697b_row18_col2" class="data row18 col2" >50</td>
#       <td id="T_e697b_row18_col3" class="data row18 col3" >4227.26</td>
#       <td id="T_e697b_row18_col4" class="data row18 col4" >5.00</td>
#     </tr>
#     <tr>
#       <td id="T_e697b_row19_col0" class="data row19 col0" >pact</td>
#       <td id="T_e697b_row19_col1" class="data row19 col1" >NN</td>
#       <td id="T_e697b_row19_col2" class="data row19 col2" >47</td>
#       <td id="T_e697b_row19_col3" class="data row19 col3" >3973.62</td>
#       <td id="T_e697b_row19_col4" class="data row19 col4" >4.70</td>
#     </tr>
#     <tr>
#       <td id="T_e697b_row20_col0" class="data row20 col0" >rare</td>
#       <td id="T_e697b_row20_col1" class="data row20 col1" >JJ</td>
#       <td id="T_e697b_row20_col2" class="data row20 col2" >47</td>
#       <td id="T_

# %% [markdown]
# ## Trial 2 Ngram tables

# %% [markdown]
# ### Trial 2.1 Node word "change" with a span of 3 (i.e. triagrams) as example:

# %%
nc = ngrams_by_token(tp, node_word='change', n_tokens=non_punct, node_position=1, span=3, search_type='fixed', count_by='pos')

# %%
nc.head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d1e28">
#   <thead>
#     <tr>
#       <th id="T_d1e28_level0_col0" class="col_heading level0 col0" >Token1</th>
#       <th id="T_d1e28_level0_col1" class="col_heading level0 col1" >Token2</th>
#       <th id="T_d1e28_level0_col2" class="col_heading level0 col2" >Token3</th>
#       <th id="T_d1e28_level0_col3" class="col_heading level0 col3" >Tag1</th>
#       <th id="T_d1e28_level0_col4" class="col_heading level0 col4" >Tag2</th>
#       <th id="T_d1e28_level0_col5" class="col_heading level0 col5" >Tag3</th>
#       <th id="T_d1e28_level0_col6" class="col_heading level0 col6" >AF</th>
#       <th id="T_d1e28_level0_col7" class="col_heading level0 col7" >RF</th>
#       <th id="T_d1e28_level0_col8" class="col_heading level0 col8" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d1e28_row0_col0" class="data row0 col0" >change</td>
#       <td id="T_d1e28_row0_col1" class="data row0 col1" >extending</td>
#       <td id="T_d1e28_row0_col2" class="data row0 col2" >winter</td>
#       <td id="T_d1e28_row0_col3" class="data row0 col3" >NN</td>
#       <td id="T_d1e28_row0_col4" class="data row0 col4" >VBG</td>
#       <td id="T_d1e28_row0_col5" class="data row0 col5" >NN</td>
#       <td id="T_d1e28_row0_col6" class="data row0 col6" >14</td>
#       <td id="T_d1e28_row0_col7" class="data row0 col7" >1183.63</td>
#       <td id="T_d1e28_row0_col8" class="data row0 col8" >1.40</td>
#     </tr>
#     <tr>
#       <td id="T_d1e28_row1_col0" class="data row1 col0" >change</td>
#       <td id="T_d1e28_row1_col1" class="data row1 col1" >way</td>
#       <td id="T_d1e28_row1_col2" class="data row1 col2" >covers</td>
#       <td id="T_d1e28_row1_col3" class="data row1 col3" >NN</td>
#       <td id="T_d1e28_row1_col4" class="data row1 col4" >NN</td>
#       <td id="T_d1e28_row1_col5" class="data row1 col5" >VBZ</td>
#       <td id="T_d1e28_row1_col6" class="data row1 col6" >10</td>
#       <td id="T_d1e28_row1_col7" class="data row1 col7" >845.45</td>
#       <td id="T_d1e28_row1_col8" class="data row1 col8" >1.00</td>
#     </tr>
#     <tr>
#       <td id="T_d1e28_row2_col0" class="data row2 col0" >change</td>
#       <td id="T_d1e28_row2_col1" class="data row2 col1" >daily</td>
#       <td id="T_d1e28_row2_col2" class="data row2 col2" >life</td>
#       <td id="T_d1e28_row2_col3" class="data row2 col3" >NN</td>
#       <td id="T_d1e28_row2_col4" class="data row2 col4" >JJ</td>
#       <td id="T_d1e28_row2_col5" class="data row2 col5" >NN</td>
#       <td id="T_d1e28_row2_col6" class="data row2 col6" >7</td>
#       <td id="T_d1e28_row2_col7" class="data row2 col7" >591.82</td>
#       <td id="T_d1e28_row2_col8" class="data row2 col8" >0.70</td>
#     </tr>
#     <tr>
#       <td id="T_d1e28_row3_col0" class="data row3 col0" >change</td>
#       <td id="T_d1e28_row3_col1" class="data row3 col1" >documentary</td>
#       <td id="T_d1e28_row3_col2" class="data row3 col2" >free</td>
#       <td id="T_d1e28_row3_col3" class="data row3 col3" >NN</td>
#       <td id="T_d1e28_row3_col4" class="data row3 col4" >NN</td>
#       <td id="T_d1e28_row3_col5" class="data row3 col5" >JJ</td>
#       <td id="T_d1e28_row3_col6" class="data row3 col6" >7</td>
#       <td id="T_d1e28_row3_col7" class="data row3 col7" >591.82</td>
#       <td id="T_d1e28_row3_col8" class="data row3 col8" >0.70</td>
#     </tr>
#     <tr>
#       <td id="T_d1e28_row4_col0" class="data row4 col0" >change</td>
#       <td id="T_d1e28_row4_col1" class="data row4 col1" >documentary</td>
#       <td id="T_d1e28_row4_col2" class="data row4 col2" >leonardo</td>
#       <td id="T_d1e28_row4_col3" class="data row4 col3" >NN</td>
#       <td id="T_d1e28_row4_col4" class="data row4 col4" >NN</td>
#       <td id="T_d1e28_row4_col5" class="data row4 col5" >NNP</td>
#       <td id="T_d1e28_row4_col6" class="data row4 col6" >7</td>
#       <td id="T_d1e28_row4_col7" class="data row4 col7" >591.82</td>
#       <td id="T_d1e28_row4_col8" class="data row4 col8" >0.70</td>
#     </tr>
#     <tr>
#       <td id="T_d1e28_row5_col0" class="data row5 col0" >change</td>
#       <td id="T_d1e28_row5_col1" class="data row5 col1" >parisagreement</td>
#       <td id="T_d1e28_row5_col2" class="data row5 col2" >crucial</td>
#       <td id="T_d1e28_row5_col3" class="data row5 col3" >NN</td>
#       <td id="T_d1e28_row5_col4" class="data row5 col4" >NNP</td>
#       <td id="T_d1e28_row5_col5" class="data row5 col5" >JJ</td>
#       <td id="T_d1e28_row5_col6" class="data row5 col6" >7</td>
#       <td id="T_d1e28_row5_col7" class="data row5 col7" >591.82</td>
#       <td id="T_d1e28_row5_col8" class="data row5 col8" >0.70</td>
#     </tr>
#     <tr>
#       <td id="T_d1e28_row6_col0" class="data row6 col0" >change</td>
#       <td id="T_d1e28_row6_col1" class="data row6 col1" >prevent</td>
#       <td id="T_d1e28_row6_col2" class="data row6 col2" >catastrophe</td>
#       <td id="T_d1e28_row6_col3" class="data row6 col3" >NN</td>
#       <td id="T_d1e28_row6_col4" class="data row6 col4" >NN</td>
#       <td id="T_d1e28_row6_col5" class="data row6 col5" >NN</td>
#       <td id="T_d1e28_row6_col6" class="data row6 col6" >7</td>
#       <td id="T_d1e28_row6_col7" class="data row6 col7" >591.82</td>
#       <td id="T_d1e28_row6_col8" class="data row6 col8" >0.70</td>
#     </tr>
#     <tr>
#       <td id="T_d1e28_row7_col0" class="data row7 col0" >change</td>
#       <td id="T_d1e28_row7_col1" class="data row7 col1" >buying</td>
#       <td id="T_d1e28_row7_col2" class="data row7 col2" >wall</td>
#       <td id="T_d1e28_row7_col3" class="data row7 col3" >NN</td>
#       <td id="T_d1e28_row7_col4" class="data row7 col4" >VBG</td>
#       <td id="T_d1e28_row7_col5" class="data row7 col5" >NN</td>
#       <td id="T_d1e28_row7_col6" class="data row7 col6" >6</td>
#       <td id="T_d1e28_row7_col7" class="data row7 col7" >507.27</td>
#       <td id="T_d1e28_row7_col8" class="data row7 col8" >0.60</td>
#     </tr>
#     <tr>
#       <td id="T_d1e28_row8_col0" class="data row8 col0" >change</td>
#       <td id="T_d1e28_row8_col1" class="data row8 col1" >join</td>
#       <td id="T_d1e28_row8_col2" class="data row8 col2" >post</td>
#       <td id="T_d1e28_row8_col3" class="data row8 col3" >NN</td>
#       <td id="T_d1e28_row8_col4" class="data row8 col4" >VBP</td>
#       <td id="T_d1e28_row8_col5" class="data row8 col5" >NN</td>
#       <td id="T_d1e28_row8_col6" class="data row8 col6" >6</td>
#       <td id="T_d1e28_row8_col7" class="data row8 col7" >507.27</td>
#       <td id="T_d1e28_row8_col8" class="data row8 col8" >0.60</td>
#     </tr>
#     <tr>
#       <td id="T_d1e28_row9_col0" class="data row9 col0" >change</td>
#       <td id="T_d1e28_row9_col1" class="data row9 col1" >mentions</td>
#       <td id="T_d1e28_row9_col2" class="data row9 col2" >cable</td>
#       <td id="T_d1e28_row9_col3" class="data row9 col3" >NN</td>
#       <td id="T_d1e28_row9_col4" class="data row9 col4" >VBZ</td>
#       <td id="T_d1e28_row9_col5" class="data row9 col5" >NN</td>
#       <td id="T_d1e28_row9_col6" class="data row9 col6" >6</td>
#       <td id="T_d1e28_row9_col7" class="data row9 col7" >507.27</td>
#       <td id="T_d1e28_row9_col8" class="data row9 col8" >0.60</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Trial 2.2 Can chose tokens ending with specific suffix to explore:
# e.g. explore words end with "ing" with a span of 3

# %%
nc = ngrams_by_token(tp, node_word='ing', n_tokens=non_punct, node_position=2, span=3, search_type='ends_with', count_by='pos')

# %%
nc.head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_aab37">
#   <thead>
#     <tr>
#       <th id="T_aab37_level0_col0" class="col_heading level0 col0" >Token1</th>
#       <th id="T_aab37_level0_col1" class="col_heading level0 col1" >Token2</th>
#       <th id="T_aab37_level0_col2" class="col_heading level0 col2" >Token3</th>
#       <th id="T_aab37_level0_col3" class="col_heading level0 col3" >Tag1</th>
#       <th id="T_aab37_level0_col4" class="col_heading level0 col4" >Tag2</th>
#       <th id="T_aab37_level0_col5" class="col_heading level0 col5" >Tag3</th>
#       <th id="T_aab37_level0_col6" class="col_heading level0 col6" >AF</th>
#       <th id="T_aab37_level0_col7" class="col_heading level0 col7" >RF</th>
#       <th id="T_aab37_level0_col8" class="col_heading level0 col8" >Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_aab37_row0_col0" class="data row0 col0" >change</td>
#       <td id="T_aab37_row0_col1" class="data row0 col1" >extending</td>
#       <td id="T_aab37_row0_col2" class="data row0 col2" >winter</td>
#       <td id="T_aab37_row0_col3" class="data row0 col3" >NN</td>
#       <td id="T_aab37_row0_col4" class="data row0 col4" >VBG</td>
#       <td id="T_aab37_row0_col5" class="data row0 col5" >NN</td>
#       <td id="T_aab37_row0_col6" class="data row0 col6" >14</td>
#       <td id="T_aab37_row0_col7" class="data row0 col7" >1183.63</td>
#       <td id="T_aab37_row0_col8" class="data row0 col8" >1.40</td>
#     </tr>
#     <tr>
#       <td id="T_aab37_row1_col0" class="data row1 col0" >vortex</td>
#       <td id="T_aab37_row1_col1" class="data row1 col1" >shifting</td>
#       <td id="T_aab37_row1_col2" class="data row1 col2" >climate</td>
#       <td id="T_aab37_row1_col3" class="data row1 col3" >NN</td>
#       <td id="T_aab37_row1_col4" class="data row1 col4" >VBG</td>
#       <td id="T_aab37_row1_col5" class="data row1 col5" >NN</td>
#       <td id="T_aab37_row1_col6" class="data row1 col6" >14</td>
#       <td id="T_aab37_row1_col7" class="data row1 col7" >1183.63</td>
#       <td id="T_aab37_row1_col8" class="data row1 col8" >1.40</td>
#     </tr>
#     <tr>
#       <td id="T_aab37_row2_col0" class="data row2 col0" >global</td>
#       <td id="T_aab37_row2_col1" class="data row2 col1" >warming</td>
#       <td id="T_aab37_row2_col2" class="data row2 col2" >chinese</td>
#       <td id="T_aab37_row2_col3" class="data row2 col3" >JJ</td>
#       <td id="T_aab37_row2_col4" class="data row2 col4" >NN</td>
#       <td id="T_aab37_row2_col5" class="data row2 col5" >JJ</td>
#       <td id="T_aab37_row2_col6" class="data row2 col6" >13</td>
#       <td id="T_aab37_row2_col7" class="data row2 col7" >1099.09</td>
#       <td id="T_aab37_row2_col8" class="data row2 col8" >1.30</td>
#     </tr>
#     <tr>
#       <td id="T_aab37_row3_col0" class="data row3 col0" >global</td>
#       <td id="T_aab37_row3_col1" class="data row3 col1" >warming</td>
#       <td id="T_aab37_row3_col2" class="data row3 col2" >real</td>
#       <td id="T_aab37_row3_col3" class="data row3 col3" >JJ</td>
#       <td id="T_aab37_row3_col4" class="data row3 col4" >NN</td>
#       <td id="T_aab37_row3_col5" class="data row3 col5" >JJ</td>
#       <td id="T_aab37_row3_col6" class="data row3 col6" >11</td>
#       <td id="T_aab37_row3_col7" class="data row3 col7" >930.00</td>
#       <td id="T_aab37_row3_col8" class="data row3 col8" >1.10</td>
#     </tr>
#     <tr>
#       <td id="T_aab37_row4_col0" class="data row4 col0" >@lifeaseva</td>
#       <td id="T_aab37_row4_col1" class="data row4 col1" >taking</td>
#       <td id="T_aab37_row4_col2" class="data row4 col2" >shorter</td>
#       <td id="T_aab37_row4_col3" class="data row4 col3" >NNP</td>
#       <td id="T_aab37_row4_col4" class="data row4 col4" >VBG</td>
#       <td id="T_aab37_row4_col5" class="data row4 col5" >JJR</td>
#       <td id="T_aab37_row4_col6" class="data row4 col6" >7</td>
#       <td id="T_aab37_row4_col7" class="data row4 col7" >591.82</td>
#       <td id="T_aab37_row4_col8" class="data row4 col8" >0.70</td>
#     </tr>
#     <tr>
#       <td id="T_aab37_row5_col0" class="data row5 col0" >global</td>
#       <td id="T_aab37_row5_col1" class="data row5 col1" >warming</td>
#       <td id="T_aab37_row5_col2" class="data row5 col2" >main</td>
#       <td id="T_aab37_row5_col3" class="data row5 col3" >JJ</td>
#       <td id="T_aab37_row5_col4" class="data row5 col4" >NN</td>
#       <td id="T_aab37_row5_col5" class="data row5 col5" >JJ</td>
#       <td id="T_aab37_row5_col6" class="data row5 col6" >7</td>
#       <td id="T_aab37_row5_col7" class="data row5 col7" >591.82</td>
#       <td id="T_aab37_row5_col8" class="data row5 col8" >0.70</td>
#     </tr>
#     <tr>
#       <td id="T_aab37_row6_col0" class="data row6 col0" >showers</td>
#       <td id="T_aab37_row6_col1" class="data row6 col1" >buying</td>
#       <td id="T_aab37_row6_col2" class="data row6 col2" >reusable</td>
#       <td id="T_aab37_row6_col3" class="data row6 col3" >NNS</td>
#       <td id="T_aab37_row6_col4" class="data row6 col4" >VBG</td>
#       <td id="T_aab37_row6_col5" class="data row6 col5" >JJ</td>
#       <td id="T_aab37_row6_col6" class="data row6 col6" >7</td>
#       <td id="T_aab37_row6_col7" class="data row6 col7" >591.82</td>
#       <td id="T_aab37_row6_col8" class="data row6 col8" >0.70</td>
#     </tr>
#     <tr>
#       <td id="T_aab37_row7_col0" class="data row7 col0" >change</td>
#       <td id="T_aab37_row7_col1" class="data row7 col1" >buying</td>
#       <td id="T_aab37_row7_col2" class="data row7 col2" >wall</td>
#       <td id="T_aab37_row7_col3" class="data row7 col3" >NN</td>
#       <td id="T_aab37_row7_col4" class="data row7 col4" >VBG</td>
#       <td id="T_aab37_row7_col5" class="data row7 col5" >NN</td>
#       <td id="T_aab37_row7_col6" class="data row7 col6" >6</td>
#       <td id="T_aab37_row7_col7" class="data row7 col7" >507.27</td>
#       <td id="T_aab37_row7_col8" class="data row7 col8" >0.60</td>
#     </tr>
#     <tr>
#       <td id="T_aab37_row8_col0" class="data row8 col0" >beaches</td>
#       <td id="T_aab37_row8_col1" class="data row8 col1" >battering</td>
#       <td id="T_aab37_row8_col2" class="data row8 col2" >scientists</td>
#       <td id="T_aab37_row8_col3" class="data row8 col3" >NNS</td>
#       <td id="T_aab37_row8_col4" class="data row8 col4" >VBG</td>
#       <td id="T_aab37_row8_col5" class="data row8 col5" >NNS</td>
#       <td id="T_aab37_row8_col6" class="data row8 col6" >5</td>
#       <td id="T_aab37_row8_col7" class="data row8 col7" >422.73</td>
#       <td id="T_aab37_row8_col8" class="data row8 col8" >0.50</td>
#     </tr>
#     <tr>
#       <td id="T_aab37_row9_col0" class="data row9 col0" >global</td>
#       <td id="T_aab37_row9_col1" class="data row9 col1" >warming</td>
#       <td id="T_aab37_row9_col2" class="data row9 col2" >climate</td>
#       <td id="T_aab37_row9_col3" class="data row9 col3" >JJ</td>
#       <td id="T_aab37_row9_col4" class="data row9 col4" >NN</td>
#       <td id="T_aab37_row9_col5" class="data row9 col5" >NN</td>
#       <td id="T_aab37_row9_col6" class="data row9 col6" >5</td>
#       <td id="T_aab37_row9_col7" class="data row9 col7" >422.73</td>
#       <td id="T_aab37_row9_col8" class="data row9 col8" >0.50</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Trial 2.3 N-gram table with specific category(collect n-grams using the ngrams_by_tag function)
# * Tried "positive", "negative","academic terms","ConfidenceHigh", "Character", but no result showed. Need to find out why?

# %%
nc = ngrams_by_tag(tp, tag='ConfidenceHigh', n_tokens=non_punct, tag_position=3, span=3, search_type='fixed', count_by='ds')
# Out:
# Your n-gram search did not return any results.

# %%
nc.head(10).style.hide(axis='index').format(precision=2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 nc.head(10).style.hide(axis='index').format(precision=2)
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %% [markdown]
# ### Trial 3.1 Collocations
# e.g. filter the collocation with the word "change" only when it's tagged as noun

# %%
ct = coll_table(tp, 'change', node_tag='NN', statistic='pmi', count_by='pos')

# %%
ct.head(20).style.hide(axis='index').format(precisi on=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_bfec6">
#   <thead>
#     <tr>
#       <th id="T_bfec6_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_bfec6_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_bfec6_level0_col2" class="col_heading level0 col2" >Freq Span</th>
#       <th id="T_bfec6_level0_col3" class="col_heading level0 col3" >Freq Total</th>
#       <th id="T_bfec6_level0_col4" class="col_heading level0 col4" >MI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bfec6_row0_col0" class="data row0 col0" >alarmism</td>
#       <td id="T_bfec6_row0_col1" class="data row0 col1" >NN</td>
#       <td id="T_bfec6_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_bfec6_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_bfec6_row0_col4" class="data row0 col4" >4.86</td>
#     </tr>
#     <tr>
#       <td id="T_bfec6_row1_col0" class="data row1 col0" >dumb</td>
#       <td id="T_bfec6_row1_col1" class="data row1 col1" >JJ</td>
#       <td id="T_bfec6_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_bfec6_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_bfec6_row1_col4" class="data row1 col4" >4.86</td>
#     </tr>
#     <tr>
#       <td id="T_bfec6_row2_col0" class="data row2 col0" >eachother</td>
#       <td id="T_bfec6_row2_col1" class="data row2 col1" >NN</td>
#       <td id="T_bfec6_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_bfec6_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_bfec6_row2_col4" class="data row2 col4" >4.86</td>
#     </tr>
#     <tr>
#       <td id="T_bfec6_row3_col0" class="data row3 col0" >find</td>
#       <td id="T_bfec6_row3_col1" class="data row3 col1" >VBP</td>
#       <td id="T_bfec6_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_bfec6_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_bfec6_row3_col4" class="data row3 col4" >4.86</td>
#     </tr>
#     <tr>
#       <td id="T_bfec6_row4_col0" class="data row4 col0" >pledges</td>
#       <td id="T_bfec6_row4_col1" class="data row4 col1" >VBZ</td>
#       <td id="T_bfec6_row4_col2" class="data row4 col2" >2</td>
#       <td id="T_bfec6_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_bfec6_row4_col4" class="data row4 col4" >4.86</td>
#     </tr>
#     <tr>
#       <td id="T_bfec6_row5_col0" class="data row5 col0" >stop</td>
#       <td id="T_bfec6_row5_col1" class="data row5 col1" >NN</td>
#       <td id="T_bfec6_row5_col2" class="data row5 col2" >2</td>
#       <td id="T_bfec6_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_bfec6_row5_col4" class="data row5 col4" >4.86</td>
#     </tr>
#     <tr>
#       <td id="T_bfec6_row6_col0" class="data row6 col0" >strict</td>
#       <td id="T_bfec6_row6_col1" class="data row6 col1" >JJ</td>
#       <td id="T_bfec6_row6_col2" class="data row6 col2" >2</td>
#       <td id="T_bfec6_row6_col3" class="data row6 col3" >1</td>
#       <td id="T_bfec6_row6_col4" class="data row6 col4" >4.86</td>
#     </tr>
#     <tr>
#       <td id="T_bfec6_row7_col0" class="data row7 col0" >believe</td>
#       <td id="T_bfec6_row7_col1" class="data row7 col1" >NN</td>
#       <td id="T_bfec6_row7_col2" class="data row7 col2" >3</td>
#       <td id="T_bfec6_row7_col3" class="data row7 col3" >2</td>
#       <td id="T_bfec6_row7_col4" class="data row7 col4" >4.44</td>
#     </tr>
#     <tr>
#       <td id="T_bfec6_row8_col0" class="data row8 col0" >citizens</td>
#       <td id="T_bfec6_row8_col1" class="data row8 col1" >NNS</td>
#       <td id="T_bfec6_row8_col2" class="data row8 col2" >3</td>
#       <td id="T_bfec6_row8_col3" class="data row8 col3" >2</td>
#       <td id="T_bfec6_row8_col4" class="data row8 col4" >4.44</td>
#     </tr>
#     <tr>
#       <td id="T_bfec6_row9_col0" class="data row9 col0" >convince</td>
#       <td id="T_bfec6_row9_col1" class="data row9 col1" >VBP</td>
#       <td id="T_bfec6_row9_col2" class="data row9 col2" >3</td>
#       <td id="T_bfec6_row9_col3" class="data row9 col3" >2</td>
#       <td id="T_bfec6_row9_col4" class="data row9 col4" >4.44</td>
#     </tr>
#     <tr>
#       <td id="T_bfec6_row10_col0" class="data row10 col0" >listen</td>
#       <td id="T_bfec6_row10_col1" class="data row10 col1" >NN</td>
#       <td id="T_bfec6_row10_col2" class="data row10 col2" >3</td>
#       <td id="T_bfec6_row10_col3" class="data row10 col3" >2</td>
#       <td id="T_bfec6_row10_col4" class="data row10 col4" >4.44</td>
#     </tr>
#     <tr>
#       <td id="T_bfec6_row11_col0" class="data row11 col0" >-bob</td>
#       <td id="T_bfec6_row11_col1" class="data row11 col1" >:</td>
#       <td id="T_bfec6_row11_col2" class="data row11 col2" >1</td>
#       <td id="T_bfec6_row11_col3" class="data row11 col3" >1</td>
#       <td id="T_bfec6_row11_col4" class="data row11 col4" >3.86</td>
#     </tr>
#     <tr>
#       <td id="T_bfec6_row12_col0" class="data row12 col0" >//channels.feeddigest.com</td>
#       <td id="T_bfec6_row12_col1" class="data row12 col1" >NFP</td>
#       <td id="T_bfec6_row12_col2" class="data row12 col2" >1</td>
#       <td id="T_bfec6_row12_col3" class="data row12 col3" >1</td>
#       <td id="T_bfec6_row12_col4" class="data row12 col4" >3.86</td>
#     </tr>
#     <tr>
#       <td id="T_bfec6_row13_col0" class="data row13 col0" >20)unchecked</td>
#       <td id="T_bfec6_row13_col1" class="data row13 col1" >VBN</td>
#       <td id="T_bfec6_row13_col2" class="data row13 col2" >1</td>
#       <td id="T_bfec6_row13_col3" class="data row13 col3" >1</td>
#       <td id="T_bfec6_row13_col4" class="data row13 col4" >3.86</td>
#     </tr>
#     <tr>
#       <td id="T_bfec6_row14_col0" class="data row14 col0" >9gag</td>
#       <td id="T_bfec6_row14_col1" class="data row14 col1" >NN</td>
#       <td id="T_bfec6_row14_col2" class="data row14 col2" >1</td>
#       <td id="T_bfec6_row14_col3" class="data row14 col3" >1</td>
#       <td id="T_bfec6_row14_col4" class="data row14 col4" >3.86</td>
#     </tr>
#     <tr>
#       <td id="T_bfec6_row15_col0" class="data row15 col0" >@21cf</td>
#       <td id="T_bfec6_row15_col1" class="data row15 col1" >.</td>
#       <td id="T_bfec6_row15_col2" class="data row15 col2" >2</td>
#       <td id="T_bfec6_row15_col3" class="data row15 col3" >2</td>
#       <td id="T_bfec6_row15_col4" class="data row15 col4" >3.86</td>
#     </tr>
#     <tr>
#       <td id="T_bfec6_row16_col0" class="data row16 col0" >@350pacific</td>
#       <td id="T_bfec6_row16_col1" class="data row16 col1" >JJ</td>
#       <td id="T_bfec6_row16_col2" class="data row16 col2" >1</td>
#       <td id="T_bfec6_row16_col3" class="data row16 col3" >1</td>
#       <td id="T_bfec6_row16_col4" class="data row16 col4" >3.86</td>
#     </tr>
#     <tr>
#       <td id="T_bfec6_row17_col0" class="data row17 col0" >@94kristin</td>
#       <td id="T_bfec6_row17_col1" class="data row17 col1" >NNP</td>
#       <td id="T_bfec6_row17_col2" class="data row17 col2" >1</td>
#       <td id="T_bfec6_row17_col3" class="data row17 col3" >1</td>
#       <td id="T_bfec6_row17_col4" class="data row17 col4" >3.86</td>
#     </tr>
#     <tr>
#       <td id="T_bfec6_row18_col0" class="data row18 col0" >@abc</td>
#       <td id="T_bfec6_row18_col1" class="data row18 col1" >NN</td>
#       <td id="T_bfec6_row18_col2" class="data row18 col2" >1</td>
#       <td id="T_bfec6_row18_col3" class="data row18 col3" >1</td>
#       <td id="T_bfec6_row18_col4" class="data row18 col4" >3.86</td>
#     </tr>
#     <tr>
#       <td id="T_bfec6_row19_col0" class="data row19 col0" >@abccompass</td>
#       <td id="T_bfec6_row19_col1" class="data row19 col1" >NNP</td>
#       <td id="T_bfec6_row19_col2" class="data row19 col2" >1</td>
#       <td id="T_bfec6_row19_col3" class="data row19 col3" >1</td>
#       <td id="T_bfec6_row19_col4" class="data row19 col4" >3.86</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Trial 3.2 Filter collocations with frequency and MI
# e.g. total frequency > 5 and MI > 3:

# %%
ct.query('`Freq Total` > 5 and MI > 3 and Tag.str.startswith("V")').head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_4e371">
#   <thead>
#     <tr>
#       <th id="T_4e371_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_4e371_level0_col1" class="col_heading level0 col1" >Tag</th>
#       <th id="T_4e371_level0_col2" class="col_heading level0 col2" >Freq Span</th>
#       <th id="T_4e371_level0_col3" class="col_heading level0 col3" >Freq Total</th>
#       <th id="T_4e371_level0_col4" class="col_heading level0 col4" >MI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4e371_row0_col0" class="data row0 col0" >covered</td>
#       <td id="T_4e371_row0_col1" class="data row0 col1" >VBN</td>
#       <td id="T_4e371_row0_col2" class="data row0 col2" >11</td>
#       <td id="T_4e371_row0_col3" class="data row0 col3" >11</td>
#       <td id="T_4e371_row0_col4" class="data row0 col4" >3.86</td>
#     </tr>
#     <tr>
#       <td id="T_4e371_row1_col0" class="data row1 col0" >covers</td>
#       <td id="T_4e371_row1_col1" class="data row1 col1" >VBZ</td>
#       <td id="T_4e371_row1_col2" class="data row1 col2" >10</td>
#       <td id="T_4e371_row1_col3" class="data row1 col3" >10</td>
#       <td id="T_4e371_row1_col4" class="data row1 col4" >3.86</td>
#     </tr>
#     <tr>
#       <td id="T_4e371_row2_col0" class="data row2 col0" >explore</td>
#       <td id="T_4e371_row2_col1" class="data row2 col1" >VB</td>
#       <td id="T_4e371_row2_col2" class="data row2 col2" >7</td>
#       <td id="T_4e371_row2_col3" class="data row2 col3" >7</td>
#       <td id="T_4e371_row2_col4" class="data row2 col4" >3.86</td>
#     </tr>
#     <tr>
#       <td id="T_4e371_row3_col0" class="data row3 col0" >extending</td>
#       <td id="T_4e371_row3_col1" class="data row3 col1" >VBG</td>
#       <td id="T_4e371_row3_col2" class="data row3 col2" >14</td>
#       <td id="T_4e371_row3_col3" class="data row3 col3" >14</td>
#       <td id="T_4e371_row3_col4" class="data row3 col4" >3.86</td>
#     </tr>
#     <tr>
#       <td id="T_4e371_row4_col0" class="data row4 col0" >fight</td>
#       <td id="T_4e371_row4_col1" class="data row4 col1" >VBP</td>
#       <td id="T_4e371_row4_col2" class="data row4 col2" >7</td>
#       <td id="T_4e371_row4_col3" class="data row4 col3" >7</td>
#       <td id="T_4e371_row4_col4" class="data row4 col4" >3.86</td>
#     </tr>
#     <tr>
#       <td id="T_4e371_row5_col0" class="data row5 col0" >finds</td>
#       <td id="T_4e371_row5_col1" class="data row5 col1" >VBZ</td>
#       <td id="T_4e371_row5_col2" class="data row5 col2" >13</td>
#       <td id="T_4e371_row5_col3" class="data row5 col3" >13</td>
#       <td id="T_4e371_row5_col4" class="data row5 col4" >3.86</td>
#     </tr>
#     <tr>
#       <td id="T_4e371_row6_col0" class="data row6 col0" >join</td>
#       <td id="T_4e371_row6_col1" class="data row6 col1" >VBP</td>
#       <td id="T_4e371_row6_col2" class="data row6 col2" >6</td>
#       <td id="T_4e371_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_4e371_row6_col4" class="data row6 col4" >3.86</td>
#     </tr>
#     <tr>
#       <td id="T_4e371_row7_col0" class="data row7 col0" >linked</td>
#       <td id="T_4e371_row7_col1" class="data row7 col1" >VBD</td>
#       <td id="T_4e371_row7_col2" class="data row7 col2" >9</td>
#       <td id="T_4e371_row7_col3" class="data row7 col3" >9</td>
#       <td id="T_4e371_row7_col4" class="data row7 col4" >3.86</td>
#     </tr>
#     <tr>
#       <td id="T_4e371_row8_col0" class="data row8 col0" >protect</td>
#       <td id="T_4e371_row8_col1" class="data row8 col1" >VB</td>
#       <td id="T_4e371_row8_col2" class="data row8 col2" >8</td>
#       <td id="T_4e371_row8_col3" class="data row8 col3" >8</td>
#       <td id="T_4e371_row8_col4" class="data row8 col4" >3.86</td>
#     </tr>
#     <tr>
#       <td id="T_4e371_row9_col0" class="data row9 col0" >shifting</td>
#       <td id="T_4e371_row9_col1" class="data row9 col1" >VBG</td>
#       <td id="T_4e371_row9_col2" class="data row9 col2" >14</td>
#       <td id="T_4e371_row9_col3" class="data row9 col3" >14</td>
#       <td id="T_4e371_row9_col4" class="data row9 col4" >3.86</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Trial 3.3 calculate collocations while ignoring tags completely by setting tag_ignore to ‘True’:

# %%
ct = coll_table(tp, 'change', tag_ignore=True, statistic='npmi')
ct.head(10).style.hide(axis='index').format(precision=2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_80218">
#   <thead>
#     <tr>
#       <th id="T_80218_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_80218_level0_col1" class="col_heading level0 col1" >Freq Span</th>
#       <th id="T_80218_level0_col2" class="col_heading level0 col2" >Freq Total</th>
#       <th id="T_80218_level0_col3" class="col_heading level0 col3" >MI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_80218_row0_col0" class="data row0 col0" >climate</td>
#       <td id="T_80218_row0_col1" class="data row0 col1" >795</td>
#       <td id="T_80218_row0_col2" class="data row0 col2" >811</td>
#       <td id="T_80218_row0_col3" class="data row0 col3" >1.00</td>
#     </tr>
#     <tr>
#       <td id="T_80218_row1_col0" class="data row1 col0" >tackle</td>
#       <td id="T_80218_row1_col1" class="data row1 col1" >105</td>
#       <td id="T_80218_row1_col2" class="data row1 col2" >105</td>
#       <td id="T_80218_row1_col3" class="data row1 col3" >0.57</td>
#     </tr>
#     <tr>
#       <td id="T_80218_row2_col0" class="data row2 col0" >travels</td>
#       <td id="T_80218_row2_col1" class="data row2 col1" >104</td>
#       <td id="T_80218_row2_col2" class="data row2 col2" >104</td>
#       <td id="T_80218_row2_col3" class="data row2 col3" >0.57</td>
#     </tr>
#     <tr>
#       <td id="T_80218_row3_col0" class="data row3 col0" >world</td>
#       <td id="T_80218_row3_col1" class="data row3 col1" >120</td>
#       <td id="T_80218_row3_col2" class="data row3 col2" >131</td>
#       <td id="T_80218_row3_col3" class="data row3 col3" >0.56</td>
#     </tr>
#     <tr>
#       <td id="T_80218_row4_col0" class="data row4 col0" >https://t.co/lkdehj3tnn</td>
#       <td id="T_80218_row4_col1" class="data row4 col1" >102</td>
#       <td id="T_80218_row4_col2" class="data row4 col2" >102</td>
#       <td id="T_80218_row4_col3" class="data row4 col3" >0.56</td>
#     </tr>
#     <tr>
#       <td id="T_80218_row5_col0" class="data row5 col0" >httã¢â‚¬â</td>
#       <td id="T_80218_row5_col1" class="data row5 col1" >109</td>
#       <td id="T_80218_row5_col2" class="data row5 col2" >115</td>
#       <td id="T_80218_row5_col3" class="data row5 col3" >0.56</td>
#     </tr>
#     <tr>
#       <td id="T_80218_row6_col0" class="data row6 col0" >exit</td>
#       <td id="T_80218_row6_col1" class="data row6 col1" >50</td>
#       <td id="T_80218_row6_col2" class="data row6 col2" >50</td>
#       <td id="T_80218_row6_col3" class="data row6 col3" >0.49</td>
#     </tr>
#     <tr>
#       <td id="T_80218_row7_col0" class="data row7 col0" >pact</td>
#       <td id="T_80218_row7_col1" class="data row7 col1" >49</td>
#       <td id="T_80218_row7_col2" class="data row7 col2" >49</td>
#       <td id="T_80218_row7_col3" class="data row7 col3" >0.49</td>
#     </tr>
#     <tr>
#       <td id="T_80218_row8_col0" class="data row8 col0" >plan</td>
#       <td id="T_80218_row8_col1" class="data row8 col1" >53</td>
#       <td id="T_80218_row8_col2" class="data row8 col2" >59</td>
#       <td id="T_80218_row8_col3" class="data row8 col3" >0.47</td>
#     </tr>
#     <tr>
#       <td id="T_80218_row9_col0" class="data row9 col0" >trump</td>
#       <td id="T_80218_row9_col1" class="data row9 col1" >74</td>
#       <td id="T_80218_row9_col2" class="data row9 col2" >106</td>
#       <td id="T_80218_row9_col3" class="data row9 col3" >0.45</td>
#     </tr>
#   </tbody>
# </table>
